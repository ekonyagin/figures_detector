# %%
from detector import FiguresDetector

import cv2
import matplotlib.pyplot as plt
import os

# %%
detector = FiguresDetector()

# %%
PATH = './test_pictures/'


for img_path in os.listdir(PATH):
    img = cv2.imread(os.path.join(PATH, img_path), 0)
    figures = detector.detect(img)
    plt.imshow(figures)
    plt.show()
# Out:
#        Triangle  Circle  Square  Total
# Count         1       8       5     14
#        Triangle  Circle  Square  Total
# Count         0       3       3      6
#        Triangle  Circle  Square  Total
# Count         1       1       1      3
